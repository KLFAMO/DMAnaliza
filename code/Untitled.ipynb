# %%
import numpy as np
from astropy.coordinates import get_sun
from astropy.time import Time

# Test to see if get_sun works
time = Time(60493.60420139, format='mjd')
sun = get_sun(time)
print(sun)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5j/smtb2dt92sb9sbg4ghtkmmj00000gn/T/ipykernel_6109/1629408498.py in <module>
#       5 # Test to see if get_sun works
#       6 time = Time(60493.60420139, format='mjd')
# ----> 7 sun = get_sun(time)
#       8 print(sun)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/coordinates/funcs.py in get_sun(time)
#     166                                       y=-dsun*properdir[..., 1] * u.AU,
#     167                                       z=-dsun*properdir[..., 2] * u.AU)
# --> 168     return SkyCoord(cartrep, frame=GCRS(obstime=time))
#     169
#     170
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/coordinates/sky_coordinate.py in __init__(self, copy, *args, **kwargs)
#     329             # creating the internal self._sky_coord_frame object
#     330             args = list(args)  # Make it mutable
# ...
